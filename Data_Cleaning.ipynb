# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #**Data**

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['orders-20220621-175749.csv']))
# Out:
#      <input type="file" id="files-ca8a0ff1-1af4-4748-90b8-97f94b14b762" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca8a0ff1-1af4-4748-90b8-97f94b14b762">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving orders-20220621-175749.csv to orders-20220621-175749.csv

# %% [markdown]
# ##**BTC**

# %%
#Filter data to specific asset:
btcData = df[df["Symbol.1"] == "BTC"]
#Sorted and converted to time series
btcData.index = pd.to_datetime(btcData['TransactTime'])
btcData.sort_index(inplace = True)
#Filter data to only include necessary features:
btcData = btcData[['Symbol', 'Side', 'OrderID','CumQty', 'AvgPx', 'Group']]
#Sort fills into "parent" and "child" orders
tags = []
for i in btcData.Group:
  if "contingent/" in i:
    tags.append('c')
  else:
    tags.append('p')
btcData['tag'] = tags
btcData['time'] = btcData.index
#Sorted:
btcP = btcData[btcData.tag == "p"]
btcC = btcData[btcData.tag == "c"]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:6402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   key,

# %%
btcP.head(5)
# Out:
#                                         Symbol Side  \
# TransactTime
# 2022-05-05 06:32:21.732000+00:00  ftx:BTC-PERP  Buy
# 2022-05-05 09:30:12.687000+00:00  ftx:BTC-PERP  Buy
# 2022-05-05 13:23:15.889000+00:00  ftx:BTC-PERP  Buy
# 2022-05-05 13:44:24.534000+00:00  ftx:BTC-PERP  Buy
# 2022-05-05 13:50:14.180000+00:00  ftx:BTC-PERP  Buy
#
#                                                                OrderID  \
# TransactTime
# 2022-05-05 06:32:21.732000+00:00  935e5d9e-2e40-407e-a4d4-88612064a0f4
# 2022-05-05 09:30:12.687000+00:00  64900b6a-46cc-48f3-b617-e9e9ccd42e1b
# 2022-05-05 13:23:15.889000+00:00  4477e2d2-12c1-4830-bba8-5a169fa8e157
# 2022-05-05 13:44:24.534000+00:00  2c9cabd8-e150-4478-aab3-a806a27e3ce4
# 2022-05-05 13:50:14.180000+00:00  0e2cd192-9cde-498a-92c2-ba5fd22f3635
#
#                                   CumQty        AvgPx                Group tag
# TransactTime
# 2022-05-05 06:32:21.732000+00:00  0.0149  39547.00000  Contingent(75.0bps)   p
# 2022-05-05 09:30:12.687000+00:00  0.0505  39428.00000  Contingent(75.0bps)   p
# 2022-05-05 13:23:15.889000+00:00  5.9113  39362.90557  Contingent(75.0bps)   p
# 2022-05-05 13:44:24.534000+00:00  4.7211  39242.05808  Contingent(75.0bps)   p
# 2022-05-05 13:50:14.180000+00:00  3.6612  39125.56741  Contingent(75.0bps)   p

# %%
btcData
# Out:
#                                         Symbol  Side  \
# TransactTime
# 2022-05-05 06:32:21.732000+00:00  ftx:BTC-PERP   Buy
# 2022-05-05 08:43:18.053000+00:00  ftx:BTC-PERP   Buy
# 2022-05-05 09:30:12.687000+00:00  ftx:BTC-PERP   Buy
# 2022-05-05 13:23:15.889000+00:00  ftx:BTC-PERP   Buy
# 2022-05-05 13:44:24.534000+00:00  ftx:BTC-PERP   Buy
# ...                                        ...   ...
# 2022-06-10 16:28:30.211000+00:00  ftx:BTC-PERP   Buy
# 2022-06-10 20:22:02.580000+00:00  ftx:BTC-PERP  Sell
# 2022-06-11 05:08:15.456000+00:00  ftx:BTC-PERP  Sell
# 2022-05-05 13:23:15.889000+00:00   p 2022-05-05 13:23:15.889000+00:00
# 2022-05-05 13:44:24.534000+00:00   p 2022-05-05 13:44:24.534000+00:00
# ...                               ..                              ...
# 2022-06-10 16:28:30.211000+00:00   p 2022-06-10 16:28:30.211000+00:00
# 2022-06-10 20:22:02.580000+00:00   c 2022-06-10 20:22:02.580000+00:00
# 2022-06-11 05:08:15.456000+00:00   c 2022-06-11 05:08:15.456000+00:00
# 2022-06-11 08:37:28.993000+00:00   c 2022-06-11 08:37:28.993000+00:00
# 2022-06-11 09:00:11.842000+00:00   c 2022-06-11 09:00:11.842000+00:00
#
#                                   timeDiff_normalized  pxChange      logPx
# TransactTime
# 2022-05-05 06:32:21.732000+00:00                  NaN       NaN  10.585245
# 2022-05-05 08:43:18.053000+00:00            88.635890 -0.001732  10.583513
# 2022-05-05 09:30:12.687000+00:00            53.053124 -0.001282  10.582232
# 2022-05-05 13:23:15.889000+00:00           118.250590 -0.001652  10.580579
# 2022-05-05 13:44:24.534000+00:00            35.618043 -0.003075  10.577504
# ...                                               ...       ...        ...
# 2022-06-10 16:28:30.211000+00:00             4.543347 -0.007816  10.272014
# 2022-06-10 20:22:02.580000+00:00           118.373853  0.009569  10.281583
# 2022-06-11 05:08:15.456000+00:00           177.687580  0.007316  10.288899
# 2022-06-11 08:37:28.993000+00:00           112.042568 -0.007660  10.281239
# 2022-06-11 09:00:11.842000+00:00            36.916785 -0.009120  10.272120
#
# [599 rows x 11 columns]

# %%
import datetime
from datetime import timedelta
import math
second = timedelta(seconds = 1)
btcData['timeDiff_normalized'] = ((btcData.time - btcData.time.shift(1))/second)**0.5
btcData['pxChange'] = (np.log(btcData.AvgPx) - np.log(btcData.AvgPx.shift(1)))
out = btcData['pxChange']/btcData['timeDiff_normalized']

# %%
totalTime = np.sum(((btcData.time - btcData.time.shift(1))/second))
totalTime
# Out:
# 3205670.11

# %%
out.describe()['std']/np.sqrt(12)
# Out:
# 0.0005506107349632043

# %% [markdown]
# ##**ETH Data**

# %%
#Filter data to specific asset:
ethData = df[df["Symbol.1"] == "ETH"]
#Sorted and converted to time series
ethData.index = pd.to_datetime(ethData['TransactTime'])
ethData.sort_index(inplace = True)
#Filter data to only include necessary features:
ethData = ethData[['Symbol', 'Side', 'OrderID','CumQty', 'AvgPx', 'Group']]
#Sort fills into "parent" and "child" orders
tags = []
for i in ethData.Group:
  if "contingent/" in i:
    tags.append('c')
  else:
    tags.append('p')
ethData['tag'] = tags

#Sorted:
ethP = ethData[ethData.tag == "p"]
ethC = ethData[ethData.tag == "c"]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:6402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   key,

# %%
ethP.head(5)
# Out:
#                                         Symbol Side  \
# TransactTime
# 2022-05-05 05:55:05.432000+00:00  ftx:ETH-PERP  Buy
# 2022-05-05 08:04:21.662000+00:00  ftx:ETH-PERP  Buy
# 2022-05-05 14:56:24.286000+00:00  ftx:ETH-PERP  Buy
# 2022-05-05 14:58:37.016000+00:00  ftx:ETH-PERP  Buy
# 2022-05-05 15:04:20.783000+00:00  ftx:ETH-PERP  Buy
#
#                                                                OrderID  \
# TransactTime
